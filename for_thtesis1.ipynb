# %% [markdown]
# <a href="https://colab.research.google.com/github/ramonafabri/first/blob/main/for_thtesis1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install plotly

# %%
import plotly.express as px

# Data
counties = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
            'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
            'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
            'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

births = [12350, 3650, 2500, 2600, 4300, 1900, 1800, 2800, 2200, 1700, 6550, 2500, 1650, 5150, 3150, 5650, 4450, 2400, 3200]

# Create a bar chart
fig = px.bar(x=counties, y=births, labels={'x': 'County', 'y': 'Number of Births'},
             title='Number of Births in Hungarian Counties')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Data
counties = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
            'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
            'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
            'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

births = [12350, 3650, 2500, 2600, 4300, 1900, 1800, 2800, 2200, 1700, 6550, 2500, 1650, 5150, 3150, 5650, 4450, 2400, 3200]

regions = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
           'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
           'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
           'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create a bar chart with different colors for each region
fig = px.bar(x=counties, y=births, color=regions, labels={'x': 'County', 'y': 'Number of Births'},
             title='Number of Births in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Data for foetal losses
foetal_losses = [4145, 1453, 980, 1056, 1397, 692, 852, 1334, 1428, 838, 3246, 1358, 887, 2191, 1840, 2961, 1782, 1162, 1325]

# Data for regions
regions = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
           'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
           'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
           'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Data for counties
counties = [
    'Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
    'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna',
    'Borsod-Abaúj-Zemplén', 'Heves', 'Nógrád', 'Hajdú-Bihar',
    'Jász-Nagykun-Szolnok', 'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád'
]

# Create a bar chart for foetal losses
fig = px.bar(x=counties, y=foetal_losses, color=regions,
             labels={'x': 'County', 'y': 'Number of Foetal Losses', 'color': 'Region'},
             title='Foetal Losses in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for births
counties_births = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                   'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                   'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                   'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

births = [12350, 3650, 2500, 2600, 4300, 1900, 1800, 2800, 2200, 1700, 6550, 2500, 1650, 5150, 3150, 5650, 4450, 2400, 3200]

regions_births = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                  'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                  'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                  'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Data for foetal losses
counties_losses = [
    'Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
    'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna',
    'Borsod-Abaúj-Zemplén', 'Heves', 'Nógrád', 'Hajdú-Bihar',
    'Jász-Nagykun-Szolnok', 'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád'
]

foetal_losses = [4145, 1453, 980, 1056, 1397, 692, 852, 1334, 1428, 838, 3246, 1358, 887, 2191, 1840, 2961, 1782, 1162, 1325]

regions_losses = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                   'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                   'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                   'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create DataFrames for births and foetal losses
df_births = pd.DataFrame({'County': counties_births, 'Events': births, 'Region': regions_births, 'Event Type': 'Births'})
df_losses = pd.DataFrame({'County': counties_losses, 'Events': foetal_losses, 'Region': regions_losses, 'Event Type': 'Foetal Losses'})

# Concatenate DataFrames
df_combined = pd.concat([df_births, df_losses])

# Create a grouped bar chart
fig = px.bar(df_combined, x='County', y='Events', color='Region', facet_col='Event Type',
             labels={'Events': 'Number of Events', 'color': 'Region'},
             title='Number of Births and Foetal Losses in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for births
counties_births = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                   'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                   'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                   'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

births = [12350, 3650, 2500, 2600, 4300, 1900, 1800, 2800, 2200, 1700, 6550, 2500, 1650, 5150, 3150, 5650, 4450, 2400, 3200]

regions_births = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                  'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                  'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                  'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Data for foetal losses
counties_losses = [
    'Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
    'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna',
    'Borsod-Abaúj-Zemplén', 'Heves', 'Nógrád', 'Hajdú-Bihar',
    'Jász-Nagykun-Szolnok', 'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád'
]

foetal_losses = [4145, 1453, 980, 1056, 1397, 692, 852, 1334, 1428, 838, 3246, 1358, 887, 2191, 1840, 2961, 1782, 1162, 1325]

regions_losses = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                   'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                   'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                   'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create a DataFrame for births
df_births = pd.DataFrame({'County': counties_births, 'Events': births, 'Region': regions_births, 'Event Type': 'Births'})

# Create a DataFrame for foetal losses
df_losses = pd.DataFrame({'County': counties_losses, 'Events': foetal_losses, 'Region': regions_losses, 'Event Type': 'Foetal Losses'})

# Concatenate DataFrames
df_combined = pd.concat([df_births, df_losses])

# Create a bar chart with different colors for births and foetal losses
fig = px.bar(df_combined, x='County', y='Events', color='Region', facet_col='Event Type',
             labels={'Events': 'Number of Events', 'color': 'Region'},
             title='Number of Births and Foetal Losses in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for births
counties_births = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                   'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                   'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                   'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

births = [12350, 3650, 2500, 2600, 4300, 1900, 1800, 2800, 2200, 1700, 6550, 2500, 1650, 5150, 3150, 5650, 4450, 2400, 3200]

regions_births = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                  'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                  'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                  'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Data for foetal losses
counties_losses = [
    'Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
    'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna',
    'Borsod-Abaúj-Zemplén', 'Heves', 'Nógrád', 'Hajdú-Bihar',
    'Jász-Nagykun-Szolnok', 'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád'
]

foetal_losses = [4145, 1453, 980, 1056, 1397, 692, 852, 1334, 1428, 838, 3246, 1358, 887, 2191, 1840, 2961, 1782, 1162, 1325]

regions_losses = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                   'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                   'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                   'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Combine the data into one DataFrame
df_combined = pd.DataFrame({
    'County': counties_births + counties_losses,
    'Events': births + foetal_losses,
    'Region': regions_births + regions_losses,
    'Event Type': ['Births'] * len(births) + ['Foetal Losses'] * len(foetal_losses)
})

# Create a bar chart
fig = px.bar(df_combined, x='County', y='Events', color='Event Type',
             labels={'Events': 'Number of Events', 'color': 'Event Type'},
             title='Number of Births and Foetal Losses in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for births
counties_births = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                   'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                   'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                   'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

births = [12350, 3650, 2500, 2600, 4300, 1900, 1800, 2800, 2200, 1700, 6550, 2500, 1650, 5150, 3150, 5650, 4450, 2400, 3200]

regions_births = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                  'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                  'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                  'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Data for foetal losses
counties_losses = [
    'Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
    'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna',
    'Borsod-Abaúj-Zemplén', 'Heves', 'Nógrád', 'Hajdú-Bihar',
    'Jász-Nagykun-Szolnok', 'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád'
]

foetal_losses = [4145, 1453, 980, 1056, 1397, 692, 852, 1334, 1428, 838, 3246, 1358, 887, 2191, 1840, 2961, 1782, 1162, 1325]

regions_losses = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                   'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                   'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                   'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create DataFrames for births and foetal losses
df_births = pd.DataFrame({'County': counties_births, 'Events': births, 'Region': regions_births, 'Event Type': 'Births'})
df_losses = pd.DataFrame({'County': counties_losses, 'Events': foetal_losses, 'Region': regions_losses, 'Event Type': 'Foetal Losses'})

# Concatenate DataFrames
df_combined = pd.concat([df_births, df_losses])

# Create a grouped bar chart
fig = px.bar(df_combined, x='County', y='Events', color='Region', facet_col='Event Type',
             labels={'Events': 'Number of Events', 'color': 'Region'},
             title='Number of Births and Foetal Losses in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for marriages
counties_marriages = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                      'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                      'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                      'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

marriages = [6500, 2250, 1650, 1650, 2500, 1200, 1200, 1700, 1400, 1000, 3100, 1450, 800, 2650, 1700, 2800, 2500, 1550, 2050]

regions_marriages = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                     'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                     'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                     'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create DataFrame for marriages
df_marriages = pd.DataFrame({'County': counties_marriages, 'Events': marriages, 'Region': regions_marriages, 'Event Type': 'Marriages'})

# Create a bar chart for marriages
fig = px.bar(df_marriages, x='County', y='Events', color='Region',
             labels={'Events': 'Number of Marriages', 'color': 'Region'},
             title='Number of Marriages in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for maternity and child-rearing care users
counties_maternity = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                       'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                       'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                       'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

maternity_users = [19.6, 12.8, 12.8, 12.0, 12.9, 11.8, 10.0, 10.5, 8.4, 10.4, 9, 9.1, 6.6, 11.4, 10.4, 10.2, 12.1, 10.1, 13.4]

regions_maternity = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                      'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                      'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                      'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create DataFrame for maternity and child-rearing care users
df_maternity = pd.DataFrame({'County': counties_maternity, 'Events': maternity_users, 'Region': regions_maternity, 'Event Type': 'Maternity Users'})

# Create a bar chart for maternity and child-rearing care users
fig = px.bar(df_maternity, x='County', y='Events', color='Region',
             labels={'Events': 'Number of Maternity Users', 'color': 'Region'},
             title='Maternity and Child-Rearing Care Users per Thousand Women of Childbearing Age in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for crèche providers
counties_creche = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                    'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                    'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                    'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

creche_providers = [8429, 2250, 1624, 2021, 2934, 1306, 1282, 1856, 1307, 958, 3474, 1305, 589, 3049, 2087, 3088, 3207, 1929, 3005]

regions_creche = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                   'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                   'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                   'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create DataFrame for crèche providers
df_creche = pd.DataFrame({'County': counties_creche, 'Events': creche_providers, 'Region': regions_creche, 'Event Type': 'Crèche Providers'})

# Create a bar chart for crèche providers
fig = px.bar(df_creche, x='County', y='Events', color='Region',
             labels={'Events': 'Number of Crèche Providers', 'color': 'Region'},
             title='Number of Crèche Providers (Crèche, Mini Crèche, Workplace Crèche, Family Crèche) in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for day nursery places
counties_nursery_places = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                            'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                            'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                            'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

nursery_places = [8438, 2251, 1626, 2023, 2938, 1307, 1283, 1856, 1308, 959, 3476, 1306, 589, 3049, 2087, 3088, 3207, 1929, 3005]

regions_nursery_places = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                           'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                           'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                           'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Data for children enrolled in nursery
children_enrolled = [8038, 2141, 1526, 1814, 2768, 1211, 1168, 1678, 1213, 895, 3119, 1195, 576, 2882, 1929, 2846, 3090, 1809, 2872]

regions_children_enrolled = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                              'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                              'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                              'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create DataFrame for day nursery places
df_nursery_places = pd.DataFrame({'County': counties_nursery_places, 'Events': nursery_places, 'Region': regions_nursery_places, 'Event Type': 'Day Nursery Places'})

# Create DataFrame for children enrolled in nursery
df_children_enrolled = pd.DataFrame({'County': counties_nursery_places, 'Events': children_enrolled, 'Region': regions_children_enrolled, 'Event Type': 'Children Enrolled'})

# Concatenate the two DataFrames
df_combined = pd.concat([df_nursery_places, df_children_enrolled])

# Create a bar chart for both day nursery places and children enrolled in nursery
fig = px.bar(df_combined, x='County', y='Events', color='Region', facet_col="Event Type",
             labels={'Events': 'Number of Events', 'color': 'Region'},
             title='Number of Day Nursery Places and Children Enrolled in Nursery in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for children in temporary children's homes
counties_temporary_homes = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                            'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                            'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                            'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

children_temporary_homes = [29, None, 11, None, 79, None, None, 24, None, None, 31, 30, 24, 14, 31, 55, 45, 5, 53]

regions_temporary_homes = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                           'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                           'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                           'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create DataFrame for children in temporary children's homes
df_temporary_homes = pd.DataFrame({'County': counties_temporary_homes, 'Events': children_temporary_homes, 'Region': regions_temporary_homes, 'Event Type': 'Children in Temporary Homes'})

# Create a bar chart for children in temporary children's homes
fig = px.bar(df_temporary_homes, x='County', y='Events', color='Region',
             labels={'Events': 'Number of Events', 'color': 'Region'},
             title='Number of Children in Temporary Children\'s Homes in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px
import pandas as pd

# Data for children with an identified disadvantage
counties_disadvantage = ['Pest', 'Fejér', 'Komárom-Esztergom', 'Veszprém', 'Győr-Moson-Sopron',
                          'Vas', 'Zala', 'Baranya', 'Somogy', 'Tolna', 'Borsod-Abaúj Zemplén',
                          'Heves', 'Nógrád', 'Hajdú-Bihar', 'Jász-Nagykun-Szolnok',
                          'Szabolcs-Szatmár-Bereg', 'Bács-Kiskun', 'Békés', 'Csongrád-Csanád']

children_disadvantage = [6243, 2134, 770, 1304, 622, 748, 1589, 4014, 4442, 2963, 14587, 4352, 3150, 7210, 6158, 12724, 4682, 3026, 1905]

regions_disadvantage = ['Közép-Magyarország', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Közép-Dunántúl', 'Nyugat-Dunántúl',
                         'Nyugat-Dunántúl', 'Nyugat-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl', 'Dél-Dunántúl',
                         'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Magyarország', 'Észak-Alföld',
                         'Észak-Alföld', 'Észak-Alföld', 'Dél-Alföld', 'Dél-Alföld', 'Dél-Alföld']

# Create DataFrame for children with an identified disadvantage
df_disadvantage = pd.DataFrame({'County': counties_disadvantage, 'Events': children_disadvantage, 'Region': regions_disadvantage, 'Event Type': 'Children with Identified Disadvantage'})

# Create a bar chart for children with an identified disadvantage
fig = px.bar(df_disadvantage, x='County', y='Events', color='Region',
             labels={'Events': 'Number of Events', 'color': 'Region'},
             title='Number of Children with an Identified Disadvantage in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Counties and regions data
counties_regions = [
    ('Pest', 'Közép-Magyarország'), ('Fejér', 'Közép-Dunántúl'), ('Komárom-Esztergom', 'Közép-Dunántúl'),
    ('Veszprém', 'Közép-Dunántúl'), ('Győr-Moson-Sopron', 'Nyugat-Dunántúl'), ('Vas', 'Nyugat-Dunántúl'),
    ('Zala', 'Nyugat-Dunántúl'), ('Baranya', 'Dél-Dunántúl'), ('Somogy', 'Dél-Dunántúl'), ('Tolna', 'Dél-Dunántúl'),
    ('Borsod-Abaúj Zemplén', 'Észak-Magyarország'), ('Heves', 'Észak-Magyarország'), ('Nógrád', 'Észak-Magyarország'),
    ('Hajdú-Bihar', 'Észak-Alföld'), ('Jász-Nagykun-Szolnok', 'Észak-Alföld'),
    ('Szabolcs-Szatmár-Bereg', 'Észak-Alföld'), ('Bács-Kiskun', 'Dél-Alföld'), ('Békés', 'Dél-Alföld'),
    ('Csongrád-Csanád', 'Dél-Alföld')
]

# GDP per capita data
gdp_per_capita = [5853, 7011, 6372, 5435, 6997, 5601, 4946, 4794, 4278, 5070, 4639, 4900, 3097, 5027, 4399, 3970, 5161, 4065, 5459]

# Separate counties and regions from the combined list
counties, regions = zip(*counties_regions)

# Create a DataFrame for GDP per capita
df_gdp = pd.DataFrame({'County': counties, 'GDP per Capita (thousand HUF)': gdp_per_capita, 'Region': regions})

# Create a bar chart
fig = px.bar(df_gdp, x='County', y='GDP per Capita (thousand HUF)', color='Region',
             labels={'x': 'County', 'y': 'GDP per Capita (thousand HUF)', 'color': 'Region'},
             title='Gross Domestic Product per Capita in Hungarian Counties by Region')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
